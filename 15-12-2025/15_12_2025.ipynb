# %% [markdown]
# <a href="https://colab.research.google.com/github/codingniket/Python-Training/blob/main/15-12-2025/15_12_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('Read a CSV').getOrCreate()

# %%
data = """id,name,city,age,salary
1,Arjun,Hyderabad,25,45000
2,Meera,Chennai,32,52000
3,Rajesh,Bangalore,29,61000
4,Priya,Delhi,22,38000
5,Sanjay,Mumbai,35,72000
"""

with open("employees.csv","w") as f:
    f.write(data)

# %%
df = spark.read \
.option("header","true") \
.option("inferSchema","true") \
.csv("employees.csv")

df.show()
df.printSchema()
# Out:
# +---+------+---------+---+------+
# | id|  name|     city|age|salary|
# +---+------+---------+---+------+
# |  1| Arjun|Hyderabad| 25| 45000|
# |  2| Meera|  Chennai| 32| 52000|
# |  3|Rajesh|Bangalore| 29| 61000|
# |  4| Priya|    Delhi| 22| 38000|
# |  5|Sanjay|   Mumbai| 35| 72000|
# +---+------+---------+---+------+
#
# root
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- salary: integer (nullable = true)

# %%
json_data = [
  {
    "id": 1,
    "name": "Arjun",
    "city": "Hyderabad",
    "age": 25,
    "salary": 45000
  },
  {
    "id": 2,
    "name": "Meera",
    "city": "Chennai",
    "age": 32,
    "salary": 52000
  },
  {
    "id": 3,
    "name": "Rajesh",
    "city": "Bangalore",
    "age": 29,
    "salary": 61000
  },
  {
    "id": 4,
    "name": "Priya",
       "city": "Delhi",
    "age": 22,
    "salary": 38000
  },
  {
    "id": 5,
    "name": "Sanjay",
    "city": "Mumbai",
    "age": 35,
    "salary": 72000
  }]

# %%
df_json = spark.createDataFrame(json_data)
df.write.mode("overwrite").json("employees.json")
df_json.show()
df_json.printSchema()
# Out:
# +---+---------+---+------+------+
# |age|     city| id|  name|salary|
# +---+---------+---+------+------+
# | 25|Hyderabad|  1| Arjun| 45000|
# | 32|  Chennai|  2| Meera| 52000|
# | 29|Bangalore|  3|Rajesh| 61000|
# | 22|    Delhi|  4| Priya| 38000|
# | 35|   Mumbai|  5|Sanjay| 72000|
# +---+---------+---+------+------+
#
# root
#  |-- age: long (nullable = true)
#  |-- city: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- salary: long (nullable = true)

# %%
df.write.mode("overwrite").parquet("employees.parquet")
df_parquet = spark.read.parquet("employees.parquet")
df_parquet.show()
# Out:
# +---+------+---------+---+------+
# | id|  name|     city|age|salary|
# +---+------+---------+---+------+
# |  1| Arjun|Hyderabad| 25| 45000|
# |  2| Meera|  Chennai| 32| 52000|
# |  3|Rajesh|Bangalore| 29| 61000|
# |  4| Priya|    Delhi| 22| 38000|
# |  5|Sanjay|   Mumbai| 35| 72000|
# +---+------+---------+---+------+

# %%
data = [
    ("O001","Amit","Hyderabad","Spice Hub","Indian",450,35,"UPI","Delivered"),
    ("O002","Neha","Bangalore","Pizza Town","Italian",650,40,"Card","Delivered"),
    ("O003","Rahul","Delhi","Burger Zone","American",520,30,"Cash","Delivered"),
    ("O004","Pooja","Mumbai","Sushi Bar","Japanese",1200,55,"UPI","Cancelled"),
    ("O005","Arjun","Chennai","Curry Leaf","Indian",380,28,"UPI","Delivered"),
    ("O006","Sneha","Hyderabad","Pasta Street","Italian",700,45,"Card","Delivered"),
    ("O007","Karan","Delhi","Taco Bell","Mexican",540,33,"UPI","Delivered"),
    ("O008","Riya","Bangalore","Dragon Bowl","Chinese",600,38,"Wallet","Delivered"),
    ("O009","Vikas","Mumbai","BBQ Nation","Indian",1500,60,"Card","Delivered"),
    ("O010","Anjali","Chennai","Burger Zone","American",480,32,"Cash","Delivered"),
    ("O011","Farhan","Delhi","Biryani House","Indian",520,36,"UPI","Delivered"),
    ("O012","Megha","Hyderabad","Sushi Bar","Japanese",1100,58,"Card","Cancelled"),
    ("O013","Suresh","Bangalore","Curry Leaf","Indian",420,29,"UPI","Delivered"),
    ("O014","Divya","Mumbai","Pizza Town","Italian",780,42,"Wallet","Delivered"),
    ("O015","Nikhil","Delhi","Pasta Street","Italian",690,47,"UPI","Delivered"),
    ("O016","Kavya","Chennai","Dragon Bowl","Chinese",560,34,"UPI","Delivered"),
    ("O017","Rohit","Hyderabad","BBQ Nation","Indian",1400,62,"Card","Delivered"),
    ("O018","Simran","Bangalore","Burger Zone","American",510,31,"Cash","Delivered"),
    ("O019","Ayesha","Mumbai","Taco Bell","Mexican",570,35,"UPI","Delivered"),
    ("O020","Manish","Delhi","Curry Leaf","Indian",390,27,"Wallet","Delivered"),
    ("O021","Priya","Hyderabad","Pizza Town","Italian",720,41,"Card","Delivered"),
    ("O022","Yash","Chennai","Sushi Bar","Japanese",1150,57,"UPI","Delivered"),
    ("O023","Naina","Bangalore","Pasta Street","Italian",680,44,"UPI","Delivered"),
    ("O024","Sameer","Mumbai","Dragon Bowl","Chinese",610,39,"Wallet","Delivered"),
    ("O025","Ritika","Delhi","Burger Zone","American",500,30,"Cash","Delivered"),
    ("O026","Gopal","Hyderabad","Curry Leaf","Indian",410,28,"UPI","Delivered"),
    ("O027","Tina","Bangalore","Pizza Town","Italian",760,43,"Card","Delivered"),
    ("O028","Irfan","Mumbai","BBQ Nation","Indian",1550,65,"Card","Delivered"),
    ("O029","Sahil","Chennai","Taco Bell","Mexican",590,37,"UPI","Delivered"),
    ("O030","Lavanya","Delhi","Dragon Bowl","Chinese",630,40,"Wallet","Delivered"),
    ("O031","Deepak","Hyderabad","Burger Zone","American",520,33,"Cash","Delivered"),
    ("O032","Shweta","Bangalore","Curry Leaf","Indian",450,31,"UPI","Delivered"),
    ("O033","Aman","Mumbai","Pizza Town","Italian",810,46,"Card","Delivered"),
    ("O034","Rekha","Chennai","Pasta Street","Italian",700,45,"UPI","Delivered"),
    ("O035","Zubin","Delhi","BBQ Nation","Indian",1480,63,"Card","Delivered"),
    ("O036","Pallavi","Hyderabad","Dragon Bowl","Chinese",580,36,"Wallet","Delivered"),
    ("O037","Naveen","Bangalore","Taco Bell","Mexican",560,34,"UPI","Delivered"),
    ("O038","Sonia","Mumbai","Sushi Bar","Japanese",1180,59,"Card","Delivered"),
    ("O039","Harish","Chennai","Burger Zone","American",490,29,"Cash","Delivered"),
    ("O040","Kriti","Delhi","Curry Leaf","Indian",420,26,"UPI","Delivered")
]

columns = [
    "order_id","customer_name","city","restaurant","cuisine",
    "order_amount","delivery_time_minutes","payment_mode","order_status"
]

# %% [markdown]
# 1

# %%
df = spark.createDataFrame(data, columns)
df.write.mode("overwrite").csv("orders_csv.csv")

# %% [markdown]
# 2

# %%
df = spark.createDataFrame(data, columns)
df.write.mode("overwrite").option("header", "true").csv("orders_csv.csv")
df.show()
df.printSchema()
# Out:
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# |order_id|customer_name|     city|   restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# |    O001|         Amit|Hyderabad|    Spice Hub|  Indian|         450|                   35|         UPI|   Delivered|
# |    O002|         Neha|Bangalore|   Pizza Town| Italian|         650|                   40|        Card|   Delivered|
# |    O003|        Rahul|    Delhi|  Burger Zone|American|         520|                   30|        Cash|   Delivered|
# |    O004|        Pooja|   Mumbai|    Sushi Bar|Japanese|        1200|                   55|         UPI|   Cancelled|
# |    O005|        Arjun|  Chennai|   Curry Leaf|  Indian|         380|                   28|         UPI|   Delivered|
# |    O006|        Sneha|Hyderabad| Pasta Street| Italian|         700|                   45|        Card|   Delivered|
# |    O007|        Karan|    Delhi|    Taco Bell| Mexican|         540|                   33|         UPI|   Delivered|
# |    O008|         Riya|Bangalore|  Dragon Bowl| Chinese|         600|                   38|      Wallet|   Delivered|
# |    O009|        Vikas|   Mumbai|   BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|
# |    O010|       Anjali|  Chennai|  Burger Zone|American|         480|                   32|        Cash|   Delivered|
# |    O011|       Farhan|    Delhi|Biryani House|  Indian|         520|                   36|         UPI|   Delivered|
# |    O012|        Megha|Hyderabad|    Sushi Bar|Japanese|        1100|                   58|        Card|   Cancelled|
# |    O013|       Suresh|Bangalore|   Curry Leaf|  Indian|         420|                   29|         UPI|   Delivered|
# |    O014|        Divya|   Mumbai|   Pizza Town| Italian|         780|                   42|      Wallet|   Delivered|
# |    O015|       Nikhil|    Delhi| Pasta Street| Italian|         690|                   47|         UPI|   Delivered|
# |    O016|        Kavya|  Chennai|  Dragon Bowl| Chinese|         560|                   34|         UPI|   Delivered|
# |    O017|        Rohit|Hyderabad|   BBQ Nation|  Indian|        1400|                   62|        Card|   Delivered|
# |    O018|       Simran|Bangalore|  Burger Zone|American|         510|                   31|        Cash|   Delivered|
# |    O019|       Ayesha|   Mumbai|    Taco Bell| Mexican|         570|                   35|         UPI|   Delivered|
# |    O020|       Manish|    Delhi|   Curry Leaf|  Indian|         390|                   27|      Wallet|   Delivered|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# only showing top 20 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- restaurant: string (nullable = true)
#  |-- cuisine: string (nullable = true)
#  |-- order_amount: long (nullable = true)
#  |-- delivery_time_minutes: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
spend = df.filter(df.order_amount > 700).show()
# Out:
# +--------+-------------+---------+----------+--------+------------+---------------------+------------+------------+
# |order_id|customer_name|     city|restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|
# +--------+-------------+---------+----------+--------+------------+---------------------+------------+------------+
# |    O004|        Pooja|   Mumbai| Sushi Bar|Japanese|        1200|                   55|         UPI|   Cancelled|
# |    O009|        Vikas|   Mumbai|BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|
# |    O012|        Megha|Hyderabad| Sushi Bar|Japanese|        1100|                   58|        Card|   Cancelled|
# |    O014|        Divya|   Mumbai|Pizza Town| Italian|         780|                   42|      Wallet|   Delivered|
# |    O017|        Rohit|Hyderabad|BBQ Nation|  Indian|        1400|                   62|        Card|   Delivered|
# |    O021|        Priya|Hyderabad|Pizza Town| Italian|         720|                   41|        Card|   Delivered|
# |    O022|         Yash|  Chennai| Sushi Bar|Japanese|        1150|                   57|         UPI|   Delivered|
# |    O027|         Tina|Bangalore|Pizza Town| Italian|         760|                   43|        Card|   Delivered|
# |    O028|        Irfan|   Mumbai|BBQ Nation|  Indian|        1550|                   65|        Card|   Delivered|
# |    O033|         Aman|   Mumbai|Pizza Town| Italian|         810|                   46|        Card|   Delivered|
# |    O035|        Zubin|    Delhi|BBQ Nation|  Indian|        1480|                   63|        Card|   Delivered|
# |    O038|        Sonia|   Mumbai| Sushi Bar|Japanese|        1180|                   59|        Card|   Delivered|
# +--------+-------------+---------+----------+--------+------------+---------------------+------------+------------+

# %% [markdown]
# 3

# %%
spec = df.select("order_id","city","cuisine","order_amount")
spec.show()
# Out:
# +--------+---------+--------+------------+
# |order_id|     city| cuisine|order_amount|
# +--------+---------+--------+------------+
# |    O001|Hyderabad|  Indian|         450|
# |    O002|Bangalore| Italian|         650|
# |    O003|    Delhi|American|         520|
# |    O004|   Mumbai|Japanese|        1200|
# |    O005|  Chennai|  Indian|         380|
# |    O006|Hyderabad| Italian|         700|
# |    O007|    Delhi| Mexican|         540|
# |    O008|Bangalore| Chinese|         600|
# |    O009|   Mumbai|  Indian|        1500|
# |    O010|  Chennai|American|         480|
# |    O011|    Delhi|  Indian|         520|
# |    O012|Hyderabad|Japanese|        1100|
# |    O013|Bangalore|  Indian|         420|
# |    O014|   Mumbai| Italian|         780|
# |    O015|    Delhi| Italian|         690|
# |    O016|  Chennai| Chinese|         560|
# |    O017|Hyderabad|  Indian|        1400|
# |    O018|Bangalore|American|         510|
# |    O019|   Mumbai| Mexican|         570|
# |    O020|    Delhi|  Indian|         390|
# +--------+---------+--------+------------+
# only showing top 20 rows

# %% [markdown]
# 4

# %%
from pyspark.sql.functions import lit, when, col
df.sort(col("delivery_time_minutes").desc()).show(truncate=False)
df.write.mode("overwrite").option("header", "true").csv("orders_csv.csv")
# Out:
# +--------+-------------+---------+------------+--------+------------+---------------------+------------+------------+
# |order_id|customer_name|city     |restaurant  |cuisine |order_amount|delivery_time_minutes|payment_mode|order_status|
# +--------+-------------+---------+------------+--------+------------+---------------------+------------+------------+
# |O028    |Irfan        |Mumbai   |BBQ Nation  |Indian  |1550        |65                   |Card        |Delivered   |
# |O035    |Zubin        |Delhi    |BBQ Nation  |Indian  |1480        |63                   |Card        |Delivered   |
# |O017    |Rohit        |Hyderabad|BBQ Nation  |Indian  |1400        |62                   |Card        |Delivered   |
# |O009    |Vikas        |Mumbai   |BBQ Nation  |Indian  |1500        |60                   |Card        |Delivered   |
# |O038    |Sonia        |Mumbai   |Sushi Bar   |Japanese|1180        |59                   |Card        |Delivered   |
# |O012    |Megha        |Hyderabad|Sushi Bar   |Japanese|1100        |58                   |Card        |Cancelled   |
# |O022    |Yash         |Chennai  |Sushi Bar   |Japanese|1150        |57                   |UPI         |Delivered   |
# |O004    |Pooja        |Mumbai   |Sushi Bar   |Japanese|1200        |55                   |UPI         |Cancelled   |
# |O015    |Nikhil       |Delhi    |Pasta Street|Italian |690         |47                   |UPI         |Delivered   |
# |O033    |Aman         |Mumbai   |Pizza Town  |Italian |810         |46                   |Card        |Delivered   |
# |O006    |Sneha        |Hyderabad|Pasta Street|Italian |700         |45                   |Card        |Delivered   |
# |O034    |Rekha        |Chennai  |Pasta Street|Italian |700         |45                   |UPI         |Delivered   |
# |O023    |Naina        |Bangalore|Pasta Street|Italian |680         |44                   |UPI         |Delivered   |
# |O027    |Tina         |Bangalore|Pizza Town  |Italian |760         |43                   |Card        |Delivered   |
# |O014    |Divya        |Mumbai   |Pizza Town  |Italian |780         |42                   |Wallet      |Delivered   |
# |O021    |Priya        |Hyderabad|Pizza Town  |Italian |720         |41                   |Card        |Delivered   |
# |O002    |Neha         |Bangalore|Pizza Town  |Italian |650         |40                   |Card        |Delivered   |
# |O030    |Lavanya      |Delhi    |Dragon Bowl |Chinese |630         |40                   |Wallet      |Delivered   |
# |O024    |Sameer       |Mumbai   |Dragon Bowl |Chinese |610         |39                   |Wallet      |Delivered   |
# |O008    |Riya         |Bangalore|Dragon Bowl |Chinese |600         |38                   |Wallet      |Delivered   |
# +--------+-------------+---------+------------+--------+------------+---------------------+------------+------------+
# only showing top 20 rows

# %% [markdown]
# 5

# %%
deli = df.filter(df.order_status == "Delivered").show()
df.write.mode("overwrite").option("header", "true").csv("delivered.csv")
# Out:
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# |order_id|customer_name|     city|   restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# |    O001|         Amit|Hyderabad|    Spice Hub|  Indian|         450|                   35|         UPI|   Delivered|
# |    O002|         Neha|Bangalore|   Pizza Town| Italian|         650|                   40|        Card|   Delivered|
# |    O003|        Rahul|    Delhi|  Burger Zone|American|         520|                   30|        Cash|   Delivered|
# |    O005|        Arjun|  Chennai|   Curry Leaf|  Indian|         380|                   28|         UPI|   Delivered|
# |    O006|        Sneha|Hyderabad| Pasta Street| Italian|         700|                   45|        Card|   Delivered|
# |    O007|        Karan|    Delhi|    Taco Bell| Mexican|         540|                   33|         UPI|   Delivered|
# |    O008|         Riya|Bangalore|  Dragon Bowl| Chinese|         600|                   38|      Wallet|   Delivered|
# |    O009|        Vikas|   Mumbai|   BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|
# |    O010|       Anjali|  Chennai|  Burger Zone|American|         480|                   32|        Cash|   Delivered|
# |    O011|       Farhan|    Delhi|Biryani House|  Indian|         520|                   36|         UPI|   Delivered|
# |    O013|       Suresh|Bangalore|   Curry Leaf|  Indian|         420|                   29|         UPI|   Delivered|
# |    O014|        Divya|   Mumbai|   Pizza Town| Italian|         780|                   42|      Wallet|   Delivered|
# |    O015|       Nikhil|    Delhi| Pasta Street| Italian|         690|                   47|         UPI|   Delivered|
# |    O016|        Kavya|  Chennai|  Dragon Bowl| Chinese|         560|                   34|         UPI|   Delivered|
# |    O017|        Rohit|Hyderabad|   BBQ Nation|  Indian|        1400|                   62|        Card|   Delivered|
# |    O018|       Simran|Bangalore|  Burger Zone|American|         510|                   31|        Cash|   Delivered|
# |    O019|       Ayesha|   Mumbai|    Taco Bell| Mexican|         570|                   35|         UPI|   Delivered|
# |    O020|       Manish|    Delhi|   Curry Leaf|  Indian|         390|                   27|      Wallet|   Delivered|
# |    O021|        Priya|Hyderabad|   Pizza Town| Italian|         720|                   41|        Card|   Delivered|
# |    O022|         Yash|  Chennai|    Sushi Bar|Japanese|        1150|                   57|         UPI|   Delivered|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# only showing top 20 rows

# %% [markdown]
# 6

# %%
city = df.filter((df.city == "Mumbai") & (df.payment_mode == "Card")).show()
# Out:
# +--------+-------------+------+----------+--------+------------+---------------------+------------+------------+
# |order_id|customer_name|  city|restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|
# +--------+-------------+------+----------+--------+------------+---------------------+------------+------------+
# |    O009|        Vikas|Mumbai|BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|
# |    O028|        Irfan|Mumbai|BBQ Nation|  Indian|        1550|                   65|        Card|   Delivered|
# |    O033|         Aman|Mumbai|Pizza Town| Italian|         810|                   46|        Card|   Delivered|
# |    O038|        Sonia|Mumbai| Sushi Bar|Japanese|        1180|                   59|        Card|   Delivered|
# +--------+-------------+------+----------+--------+------------+---------------------+------------+------------+

# %% [markdown]
# 7

# %%
df = df.withColumn("delivery_category", when(df.delivery_time_minutes > 45, "Late").otherwise("OnTime"))
df.show()
# Out:
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+-----------------+
# |order_id|customer_name|     city|   restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|delivery_category|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+-----------------+
# |    O001|         Amit|Hyderabad|    Spice Hub|  Indian|         450|                   35|         UPI|   Delivered|           OnTime|
# |    O002|         Neha|Bangalore|   Pizza Town| Italian|         650|                   40|        Card|   Delivered|           OnTime|
# |    O003|        Rahul|    Delhi|  Burger Zone|American|         520|                   30|        Cash|   Delivered|           OnTime|
# |    O004|        Pooja|   Mumbai|    Sushi Bar|Japanese|        1200|                   55|         UPI|   Cancelled|             Late|
# |    O005|        Arjun|  Chennai|   Curry Leaf|  Indian|         380|                   28|         UPI|   Delivered|           OnTime|
# |    O006|        Sneha|Hyderabad| Pasta Street| Italian|         700|                   45|        Card|   Delivered|           OnTime|
# |    O007|        Karan|    Delhi|    Taco Bell| Mexican|         540|                   33|         UPI|   Delivered|           OnTime|
# |    O008|         Riya|Bangalore|  Dragon Bowl| Chinese|         600|                   38|      Wallet|   Delivered|           OnTime|
# |    O009|        Vikas|   Mumbai|   BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|             Late|
# |    O010|       Anjali|  Chennai|  Burger Zone|American|         480|                   32|        Cash|   Delivered|           OnTime|
# |    O011|       Farhan|    Delhi|Biryani House|  Indian|         520|                   36|         UPI|   Delivered|           OnTime|
# |    O012|        Megha|Hyderabad|    Sushi Bar|Japanese|        1100|                   58|        Card|   Cancelled|             Late|
# |    O013|       Suresh|Bangalore|   Curry Leaf|  Indian|         420|                   29|         UPI|   Delivered|           OnTime|
# |    O014|        Divya|   Mumbai|   Pizza Town| Italian|         780|                   42|      Wallet|   Delivered|           OnTime|
# |    O015|       Nikhil|    Delhi| Pasta Street| Italian|         690|                   47|         UPI|   Delivered|             Late|
# |    O016|        Kavya|  Chennai|  Dragon Bowl| Chinese|         560|                   34|         UPI|   Delivered|           OnTime|
# |    O017|        Rohit|Hyderabad|   BBQ Nation|  Indian|        1400|                   62|        Card|   Delivered|             Late|
# |    O018|       Simran|Bangalore|  Burger Zone|American|         510|                   31|        Cash|   Delivered|           OnTime|
# |    O019|       Ayesha|   Mumbai|    Taco Bell| Mexican|         570|                   35|         UPI|   Delivered|           OnTime|
# |    O020|       Manish|    Delhi|   Curry Leaf|  Indian|         390|                   27|      Wallet|   Delivered|           OnTime|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# 8

# %%
df_json = spark.createDataFrame(data, columns)
df.write.mode("overwrite").json("orders_csv.json")
df_json.show()
df_json.printSchema()
# Out:
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# |order_id|customer_name|     city|   restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# |    O001|         Amit|Hyderabad|    Spice Hub|  Indian|         450|                   35|         UPI|   Delivered|
# |    O002|         Neha|Bangalore|   Pizza Town| Italian|         650|                   40|        Card|   Delivered|
# |    O003|        Rahul|    Delhi|  Burger Zone|American|         520|                   30|        Cash|   Delivered|
# |    O004|        Pooja|   Mumbai|    Sushi Bar|Japanese|        1200|                   55|         UPI|   Cancelled|
# |    O005|        Arjun|  Chennai|   Curry Leaf|  Indian|         380|                   28|         UPI|   Delivered|
# |    O006|        Sneha|Hyderabad| Pasta Street| Italian|         700|                   45|        Card|   Delivered|
# |    O007|        Karan|    Delhi|    Taco Bell| Mexican|         540|                   33|         UPI|   Delivered|
# |    O008|         Riya|Bangalore|  Dragon Bowl| Chinese|         600|                   38|      Wallet|   Delivered|
# |    O009|        Vikas|   Mumbai|   BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|
# |    O010|       Anjali|  Chennai|  Burger Zone|American|         480|                   32|        Cash|   Delivered|
# |    O011|       Farhan|    Delhi|Biryani House|  Indian|         520|                   36|         UPI|   Delivered|
# |    O012|        Megha|Hyderabad|    Sushi Bar|Japanese|        1100|                   58|        Card|   Cancelled|
# |    O013|       Suresh|Bangalore|   Curry Leaf|  Indian|         420|                   29|         UPI|   Delivered|
# |    O014|        Divya|   Mumbai|   Pizza Town| Italian|         780|                   42|      Wallet|   Delivered|
# |    O015|       Nikhil|    Delhi| Pasta Street| Italian|         690|                   47|         UPI|   Delivered|
# |    O016|        Kavya|  Chennai|  Dragon Bowl| Chinese|         560|                   34|         UPI|   Delivered|
# |    O017|        Rohit|Hyderabad|   BBQ Nation|  Indian|        1400|                   62|        Card|   Delivered|
# |    O018|       Simran|Bangalore|  Burger Zone|American|         510|                   31|        Cash|   Delivered|
# |    O019|       Ayesha|   Mumbai|    Taco Bell| Mexican|         570|                   35|         UPI|   Delivered|
# |    O020|       Manish|    Delhi|   Curry Leaf|  Indian|         390|                   27|      Wallet|   Delivered|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+
# only showing top 20 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- restaurant: string (nullable = true)
#  |-- cuisine: string (nullable = true)
#  |-- order_amount: long (nullable = true)
#  |-- delivery_time_minutes: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- order_status: string (nullable = true)

# %% [markdown]
# 9

# %%
df.write.mode("overwrite").parquet("orders_csv.parquet")
df_parquet = spark.read.parquet("orders_csv.parquet")
df_parquet.show()
# Out:
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+-----------------+
# |order_id|customer_name|     city|   restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|delivery_category|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+-----------------+
# |    O001|         Amit|Hyderabad|    Spice Hub|  Indian|         450|                   35|         UPI|   Delivered|           OnTime|
# |    O002|         Neha|Bangalore|   Pizza Town| Italian|         650|                   40|        Card|   Delivered|           OnTime|
# |    O003|        Rahul|    Delhi|  Burger Zone|American|         520|                   30|        Cash|   Delivered|           OnTime|
# |    O004|        Pooja|   Mumbai|    Sushi Bar|Japanese|        1200|                   55|         UPI|   Cancelled|             Late|
# |    O005|        Arjun|  Chennai|   Curry Leaf|  Indian|         380|                   28|         UPI|   Delivered|           OnTime|
# |    O006|        Sneha|Hyderabad| Pasta Street| Italian|         700|                   45|        Card|   Delivered|           OnTime|
# |    O007|        Karan|    Delhi|    Taco Bell| Mexican|         540|                   33|         UPI|   Delivered|           OnTime|
# |    O008|         Riya|Bangalore|  Dragon Bowl| Chinese|         600|                   38|      Wallet|   Delivered|           OnTime|
# |    O009|        Vikas|   Mumbai|   BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|             Late|
# |    O010|       Anjali|  Chennai|  Burger Zone|American|         480|                   32|        Cash|   Delivered|           OnTime|
# |    O011|       Farhan|    Delhi|Biryani House|  Indian|         520|                   36|         UPI|   Delivered|           OnTime|
# |    O012|        Megha|Hyderabad|    Sushi Bar|Japanese|        1100|                   58|        Card|   Cancelled|             Late|
# |    O013|       Suresh|Bangalore|   Curry Leaf|  Indian|         420|                   29|         UPI|   Delivered|           OnTime|
# |    O014|        Divya|   Mumbai|   Pizza Town| Italian|         780|                   42|      Wallet|   Delivered|           OnTime|
# |    O015|       Nikhil|    Delhi| Pasta Street| Italian|         690|                   47|         UPI|   Delivered|             Late|
# |    O016|        Kavya|  Chennai|  Dragon Bowl| Chinese|         560|                   34|         UPI|   Delivered|           OnTime|
# |    O017|        Rohit|Hyderabad|   BBQ Nation|  Indian|        1400|                   62|        Card|   Delivered|             Late|
# |    O018|       Simran|Bangalore|  Burger Zone|American|         510|                   31|        Cash|   Delivered|           OnTime|
# |    O019|       Ayesha|   Mumbai|    Taco Bell| Mexican|         570|                   35|         UPI|   Delivered|           OnTime|
# |    O020|       Manish|    Delhi|   Curry Leaf|  Indian|         390|                   27|      Wallet|   Delivered|           OnTime|
# +--------+-------------+---------+-------------+--------+------------+---------------------+------------+------------+-----------------+
# only showing top 20 rows

# %%
food = df_parquet.filter((df_parquet.cuisine == "Indian") & (df_parquet.order_amount > 500)).show()
# Out:
# +--------+-------------+---------+-------------+-------+------------+---------------------+------------+------------+-----------------+
# |order_id|customer_name|     city|   restaurant|cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|delivery_category|
# +--------+-------------+---------+-------------+-------+------------+---------------------+------------+------------+-----------------+
# |    O009|        Vikas|   Mumbai|   BBQ Nation| Indian|        1500|                   60|        Card|   Delivered|             Late|
# |    O011|       Farhan|    Delhi|Biryani House| Indian|         520|                   36|         UPI|   Delivered|           OnTime|
# |    O017|        Rohit|Hyderabad|   BBQ Nation| Indian|        1400|                   62|        Card|   Delivered|             Late|
# |    O028|        Irfan|   Mumbai|   BBQ Nation| Indian|        1550|                   65|        Card|   Delivered|             Late|
# |    O035|        Zubin|    Delhi|   BBQ Nation| Indian|        1480|                   63|        Card|   Delivered|             Late|
# +--------+-------------+---------+-------------+-------+------------+---------------------+------------+------------+-----------------+

# %% [markdown]
# 11

# %%
top = df.sort(col("order_amount").desc()).limit(10)
top.show()

df.write.mode("overwrite").parquet("top_10_orders.parquet")
# Out:
# +--------+-------------+---------+----------+--------+------------+---------------------+------------+------------+-----------------+
# |order_id|customer_name|     city|restaurant| cuisine|order_amount|delivery_time_minutes|payment_mode|order_status|delivery_category|
# +--------+-------------+---------+----------+--------+------------+---------------------+------------+------------+-----------------+
# |    O028|        Irfan|   Mumbai|BBQ Nation|  Indian|        1550|                   65|        Card|   Delivered|             Late|
# |    O009|        Vikas|   Mumbai|BBQ Nation|  Indian|        1500|                   60|        Card|   Delivered|             Late|
# |    O035|        Zubin|    Delhi|BBQ Nation|  Indian|        1480|                   63|        Card|   Delivered|             Late|
# |    O017|        Rohit|Hyderabad|BBQ Nation|  Indian|        1400|                   62|        Card|   Delivered|             Late|
# |    O004|        Pooja|   Mumbai| Sushi Bar|Japanese|        1200|                   55|         UPI|   Cancelled|             Late|
# |    O038|        Sonia|   Mumbai| Sushi Bar|Japanese|        1180|                   59|        Card|   Delivered|             Late|
# |    O022|         Yash|  Chennai| Sushi Bar|Japanese|        1150|                   57|         UPI|   Delivered|             Late|
# |    O012|        Megha|Hyderabad| Sushi Bar|Japanese|        1100|                   58|        Card|   Cancelled|             Late|
# |    O033|         Aman|   Mumbai|Pizza Town| Italian|         810|                   46|        Card|   Delivered|             Late|
# |    O014|        Divya|   Mumbai|Pizza Town| Italian|         780|                   42|      Wallet|   Delivered|           OnTime|
# +--------+-------------+---------+----------+--------+------------+---------------------+------------+------------+-----------------+

# %% [markdown]
# 13

# %%
df.write.mode("overwrite").parquet("x")

# %%
df_json.write.mode("overwrite").parquet("y")

# %% [markdown]
# 14

# %%
df = spark.read.parquet("x")

# Optional: ensure a single CSV file (coalesce to 1 partition)
df_single = df.coalesce(1)

# Write CSV with pipe delimiter and header
df_single.write.mode("overwrite") \
    .option("header", "true") \
    .option("delimiter", "|")

# %% [markdown]
# 15

# %%
from pyspark.sql.functions import count,sum
cuzine = df_parquet.groupBy("cuisine").agg(sum("order_amount").alias("Total"))
cuzine.show()
# Out:
# +--------+-----+
# | cuisine|Total|
# +--------+-----+
# | Mexican| 2260|
# |  Indian| 9370|
# | Chinese| 2980|
# |Japanese| 4630|
# | Italian| 6490|
# |American| 3020|
# +--------+-----+

# %% [markdown]
# 16

# %%
cuzine = df_parquet.groupBy("city").agg(count("order_amount").alias("Total"))
cuzine.show()
# Out:
# +---------+-----+
# |     city|Total|
# +---------+-----+
# |Bangalore|    8|
# |  Chennai|    7|
# |   Mumbai|    8|
# |    Delhi|    9|
# |Hyderabad|    8|
# +---------+-----+

# %% [markdown]
# 17

# %%
cuzine = df_parquet.groupBy("payment_mode").agg(count("payment_mode").alias("Total")).orderBy("Total",ascending=False)
cuzine.show()
# Out:
# +------------+-----+
# |payment_mode|Total|
# +------------+-----+
# |         UPI|   17|
# |        Card|   11|
# |        Cash|    6|
# |      Wallet|    6|
# +------------+-----+

# %% [markdown]
# C1

# %%
repartitioned_df = df.repartition(4)
repartitioned_df.write.mode("overwrite").parquet("repartitioned_orders.parquet")

# %%
df_read_repartitioned = spark.read.parquet("repartitioned_orders.parquet")
df_read_repartitioned.show()

# %% [markdown]
# C2

# %%
from pyspark.sql.functions import count, sum

report_df = df.groupBy("city").agg(
    count("order_id").alias("total_orders"),
    sum("order_amount").alias("total_revenue")
)

report_df.show()
# Out:
# +---------+------------+-------------+
# |     city|total_orders|total_revenue|
# +---------+------------+-------------+
# |Bangalore|           8|         4630|
# |  Chennai|           7|         4350|
# |   Mumbai|           8|         8200|
# |    Delhi|           9|         5690|
# |Hyderabad|           8|         5880|
# +---------+------------+-------------+

# %%
report_df.write.mode("overwrite").parquet("city_report.parquet")

# %% [markdown]
# # SET 2

# %%
data = [
("T001","Amit","Hyderabad","Ramesh","Sedan",12.5,320,28,"UPI","Completed"),
("T002","Neha","Bangalore","Suresh","Mini",8.2,210,22,"Card","Completed"),
("T003","Rahul","Delhi","Anil","Bike",5.1,120,15,"Cash","Completed"),
("T004","Pooja","Mumbai","Vikas","SUV",18.0,560,45,"UPI","Cancelled"),
("T005","Arjun","Chennai","Kumar","Mini",7.8,200,20,"UPI","Completed"),
("T006","Sneha","Hyderabad","Ramesh","Sedan",14.2,360,32,"Card","Completed"),
("T007","Karan","Delhi","Anil","Bike",6.3,140,18,"UPI","Completed"),
("T008","Riya","Bangalore","Suresh","Sedan",11.0,300,27,"Wallet","Completed"),
("T009","Vikas","Mumbai","Vijay","SUV",20.5,650,50,"Card","Completed"),
("T010","Anjali","Chennai","Kumar","Bike",4.9,110,14,"Cash","Completed"),
("T011","Farhan","Delhi","Anil","Mini",9.6,240,25,"UPI","Completed"),
("T012","Megha","Hyderabad","Ramesh","SUV",19.2,610,48,"Card","Cancel"),
("T013","Suresh","Bangalore","Suresh","Sedan",13.0,340,30,"UPI","Completed"),
("T014","Divya","Mumbai","Vikas","Mini",10.2,260,26,"Wallet","Completed"),
("T015","Nikhil","Delhi","Anil","Sedan",15.5,390,34,"UPI","Completed"),
("T016","Kavya","Chennai","Kumar","Sedan",12.1,315,29,"UPI","Completed"),
("T017","Rohit","Hyderabad","Ramesh","SUV",22.0,700,55,"Card","Completed"),
("T018","Simran","Bangalore","Suresh","Bike",5.8,130,16,"Cash","Completed"),
("T019","Ayesha","Mumbai","Vijay","Mini",9.9,250,24,"UPI","Completed"),
("T020","Manish","Delhi","Anil","Bike",6.0,135,17,"Wallet","Completed"),
("T021","Priya","Hyderabad","Ramesh","Sedan",14.8,380,33,"Card","Completed"),
("T022","Yash","Chennai","Kumar","SUV",21.3,680,52,"UPI","Completed"),
("T023","Naina","Bangalore","Suresh","Mini",10.7,270,28,"UPI","Completed"),
("T024","Sameer","Mumbai","Vikas","Sedan",13.9,350,31,"Wallet","Completed"),
("T025","Ritika","Delhi","Anil","Bike",5.4,125,16,"Cash","Completed"),
("T026","Gopal","Hyderabad","Ramesh","Mini",8.9,225,23,"UPI","Completed"),
("T027","Tina","Bangalore","Suresh","Sedan",12.6,330,29,"Card","Completed"),
("T028","Irfan","Mumbai","Vijay","SUV",23.4,740,58,"Card","Completed"),
("T029","Sahil","Chennai","Kumar","Mini",9.4,235,24,"UPI","Completed"),
("T030","Lavanya","Delhi","Anil","Sedan",14.1,365,32,"Wallet","Completed"),
("T031","Deepak","Hyderabad","Ramesh","Bike",6.7,150,18,"Cash","Completed"),
("T032","Shweta","Bangalore","Suresh","Mini",10.0,255,26,"UPI","Completed"),
("T033","Aman","Mumbai","Vikas","Sedan",15.8,395,35,"Card","Completed"),
("T034","Rekha","Chennai","Kumar","Sedan",13.5,345,30,"UPI","Completed"),
("T035","Zubin","Delhi","Anil","SUV",24.0,760,60,"Card","Completed"),
("T036","Pallavi","Hyderabad","Ramesh","Mini",9.1,230,23,"Wallet","Completed"),
("T037","Naveen","Bangalore","Suresh","Bike",5.9,135,17,"UPI","Completed"),
("T038","Sonia","Mumbai","Vijay","SUV",21.7,690,54,"Card","Completed"),
("T039","Harish","Chennai","Kumar","Mini",8.5,215,21,"Cash","Completed"),
("T040","Kriti","Delhi","Anil","Sedan",14.6,375,33,"UPI","Completed"),
("T041","Apoorva","Hyderabad","Ramesh","Sedan",13.2,335,30,"Card","Completed"),
("T042","Mohit","Bangalore","Suresh","SUV",19.9,620,49,"UPI","Completed"),
("T043","Tanvi","Mumbai","Vikas","Mini",10.4,265,27,"Wallet","Completed"),
("T044","Rakesh","Chennai","Kumar","Bike",6.2,140,18,"Cash","Completed"),
("T045","Isha","Delhi","Anil","Mini",9.7,245,25,"UPI","Completed"),
]


columns = [
"trip_id","rider_name","city","driver_name","vehicle_type",
"distance_km","trip_fare","trip_duration_minutes",
"payment_mode","trip_status"
]


df = spark.createDataFrame(data, columns)
df.show()
df.printSchema()
# Out:
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |trip_id|rider_name|     city|driver_name|vehicle_type|distance_km|trip_fare|trip_duration_minutes|payment_mode|trip_status|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |   T001|      Amit|Hyderabad|     Ramesh|       Sedan|       12.5|      320|                   28|         UPI|  Completed|
# |   T002|      Neha|Bangalore|     Suresh|        Mini|        8.2|      210|                   22|        Card|  Completed|
# |   T003|     Rahul|    Delhi|       Anil|        Bike|        5.1|      120|                   15|        Cash|  Completed|
# |   T004|     Pooja|   Mumbai|      Vikas|         SUV|       18.0|      560|                   45|         UPI|  Cancelled|
# |   T005|     Arjun|  Chennai|      Kumar|        Mini|        7.8|      200|                   20|         UPI|  Completed|
# |   T006|     Sneha|Hyderabad|     Ramesh|       Sedan|       14.2|      360|                   32|        Card|  Completed|
# |   T007|     Karan|    Delhi|       Anil|        Bike|        6.3|      140|                   18|         UPI|  Completed|
# |   T008|      Riya|Bangalore|     Suresh|       Sedan|       11.0|      300|                   27|      Wallet|  Completed|
# |   T009|     Vikas|   Mumbai|      Vijay|         SUV|       20.5|      650|                   50|        Card|  Completed|
# |   T010|    Anjali|  Chennai|      Kumar|        Bike|        4.9|      110|                   14|        Cash|  Completed|
# |   T011|    Farhan|    Delhi|       Anil|        Mini|        9.6|      240|                   25|         UPI|  Completed|
# |   T012|     Megha|Hyderabad|     Ramesh|         SUV|       19.2|      610|                   48|        Card|     Cancel|
# |   T013|    Suresh|Bangalore|     Suresh|       Sedan|       13.0|      340|                   30|         UPI|  Completed|
# |   T014|     Divya|   Mumbai|      Vikas|        Mini|       10.2|      260|                   26|      Wallet|  Completed|
# |   T015|    Nikhil|    Delhi|       Anil|       Sedan|       15.5|      390|                   34|         UPI|  Completed|
# |   T016|     Kavya|  Chennai|      Kumar|       Sedan|       12.1|      315|                   29|         UPI|  Completed|
# |   T017|     Rohit|Hyderabad|     Ramesh|         SUV|       22.0|      700|                   55|        Card|  Completed|
# |   T018|    Simran|Bangalore|     Suresh|        Bike|        5.8|      130|                   16|        Cash|  Completed|
# |   T019|    Ayesha|   Mumbai|      Vijay|        Mini|        9.9|      250|                   24|         UPI|  Completed|
# |   T020|    Manish|    Delhi|       Anil|        Bike|        6.0|      135|                   17|      Wallet|  Completed|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# only showing top 20 rows
# root
#  |-- trip_id: string (nullable = true)
#  |-- rider_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- driver_name: string (nullable = true)
#  |-- vehicle_type: string (nullable = true)
#  |-- distance_km: double (nullable = true)
#  |-- trip_fare: long (nullable = true)
#  |-- trip_duration_minutes: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- trip_status: string (nullable = true)

# %% [markdown]
# 1

# %%
df.write.mode("overwrite").option("header", "true").csv("cabs.csv")

# %% [markdown]
# 2

# %%
trip = spark.read.option("header","true").csv("cabs.csv")
# trip.show()
task = trip.filter((trip.trip_fare > 400) & (trip.trip_status == "Completed"))
task.show()
# Out:
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |trip_id|rider_name|     city|driver_name|vehicle_type|distance_km|trip_fare|trip_duration_minutes|payment_mode|trip_status|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |   T023|     Naina|Bangalore|     Suresh|        Mini|       10.7|      270|                   28|         UPI|  Completed|
# |   T024|    Sameer|   Mumbai|      Vikas|       Sedan|       13.9|      350|                   31|      Wallet|  Completed|
# |   T025|    Ritika|    Delhi|       Anil|        Bike|        5.4|      125|                   16|        Cash|  Completed|
# |   T026|     Gopal|Hyderabad|     Ramesh|        Mini|        8.9|      225|                   23|         UPI|  Completed|
# |   T027|      Tina|Bangalore|     Suresh|       Sedan|       12.6|      330|                   29|        Card|  Completed|
# |   T028|     Irfan|   Mumbai|      Vijay|         SUV|       23.4|      740|                   58|        Card|  Completed|
# |   T029|     Sahil|  Chennai|      Kumar|        Mini|        9.4|      235|                   24|         UPI|  Completed|
# |   T030|   Lavanya|    Delhi|       Anil|       Sedan|       14.1|      365|                   32|      Wallet|  Completed|
# |   T031|    Deepak|Hyderabad|     Ramesh|        Bike|        6.7|      150|                   18|        Cash|  Completed|
# |   T032|    Shweta|Bangalore|     Suresh|        Mini|       10.0|      255|                   26|         UPI|  Completed|
# |   T033|      Aman|   Mumbai|      Vikas|       Sedan|       15.8|      395|                   35|        Card|  Completed|
# |   T034|     Rekha|  Chennai|      Kumar|       Sedan|       13.5|      345|                   30|         UPI|  Completed|
# |   T035|     Zubin|    Delhi|       Anil|         SUV|       24.0|      760|                   60|        Card|  Completed|
# |   T036|   Pallavi|Hyderabad|     Ramesh|        Mini|        9.1|      230|                   23|      Wallet|  Completed|
# |   T037|    Naveen|Bangalore|     Suresh|        Bike|        5.9|      135|                   17|         UPI|  Completed|
# |   T038|     Sonia|   Mumbai|      Vijay|         SUV|       21.7|      690|                   54|        Card|  Completed|
# |   T039|    Harish|  Chennai|      Kumar|        Mini|        8.5|      215|                   21|        Cash|  Completed|
# |   T040|     Kriti|    Delhi|       Anil|       Sedan|       14.6|      375|                   33|         UPI|  Completed|
# |   T041|   Apoorva|Hyderabad|     Ramesh|       Sedan|       13.2|      335|                   30|        Card|  Completed|
# |   T042|     Mohit|Bangalore|     Suresh|         SUV|       19.9|      620|                   49|         UPI|  Completed|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# only showing top 20 rows
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |trip_id|rider_name|     city|driver_name|vehicle_type|distance_km|trip_fare|trip_duration_minutes|payment_mode|trip_status|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |   T028|     Irfan|   Mumbai|      Vijay|         SUV|       23.4|      740|                   58|        Card|  Completed|
# |   T035|     Zubin|    Delhi|       Anil|         SUV|       24.0|      760|                   60|        Card|  Completed|
# |   T038|     Sonia|   Mumbai|      Vijay|         SUV|       21.7|      690|                   54|        Card|  Completed|
# |   T042|     Mohit|Bangalore|     Suresh|         SUV|       19.9|      620|                   49|         UPI|  Completed|
# |   T009|     Vikas|   Mumbai|      Vijay|         SUV|       20.5|      650|                   50|        Card|  Completed|
# |   T017|     Rohit|Hyderabad|     Ramesh|         SUV|       22.0|      700|                   55|        Card|  Completed|
# |   T022|      Yash|  Chennai|      Kumar|         SUV|       21.3|      680|                   52|         UPI|  Completed|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+

# %% [markdown]
# 3

# %%
x = trip.select("trip_id","city","vehicle_type","trip_fare")
x.sort(col("trip_fare").desc()).show(truncate=False)
# Out:
# +-------+---------+------------+---------+
# |trip_id|city     |vehicle_type|trip_fare|
# +-------+---------+------------+---------+
# |T035   |Delhi    |SUV         |760      |
# |T028   |Mumbai   |SUV         |740      |
# |T017   |Hyderabad|SUV         |700      |
# |T038   |Mumbai   |SUV         |690      |
# |T022   |Chennai  |SUV         |680      |
# |T009   |Mumbai   |SUV         |650      |
# |T042   |Bangalore|SUV         |620      |
# |T012   |Hyderabad|SUV         |610      |
# |T004   |Mumbai   |SUV         |560      |
# |T033   |Mumbai   |Sedan       |395      |
# |T015   |Delhi    |Sedan       |390      |
# |T021   |Hyderabad|Sedan       |380      |
# |T040   |Delhi    |Sedan       |375      |
# |T030   |Delhi    |Sedan       |365      |
# |T006   |Hyderabad|Sedan       |360      |
# |T024   |Mumbai   |Sedan       |350      |
# |T034   |Chennai  |Sedan       |345      |
# |T013   |Bangalore|Sedan       |340      |
# |T041   |Hyderabad|Sedan       |335      |
# |T027   |Bangalore|Sedan       |330      |
# +-------+---------+------------+---------+
# only showing top 20 rows

# %% [markdown]
# 4

# %%
from pyspark.sql.functions import col

bike_df = df.filter(col("vehicle_type") == "Bike")

bike_df.write \
    .mode("overwrite") \
    .option("header", "true") \
    .option("delimiter", "|") \
    .csv("bike_trips.csv")

# %% [markdown]
# 5

# %%
mumbai = df.filter(df.city == "Mumbai")

mumbai.write.mode("overwrite").option("header", "true").json("mumbai.json")

# %%
mumbai = spark.read.json("mumbai.json")
mumbai.show()
# Out:
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+
# |  city|distance_km|driver_name|payment_mode|rider_name|trip_duration_minutes|trip_fare|trip_id|trip_status|vehicle_type|
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+
# |Mumbai|       13.9|      Vikas|      Wallet|    Sameer|                   31|      350|   T024|  Completed|       Sedan|
# |Mumbai|       23.4|      Vijay|        Card|     Irfan|                   58|      740|   T028|  Completed|         SUV|
# |Mumbai|       15.8|      Vikas|        Card|      Aman|                   35|      395|   T033|  Completed|       Sedan|
# |Mumbai|       21.7|      Vijay|        Card|     Sonia|                   54|      690|   T038|  Completed|         SUV|
# |Mumbai|       10.4|      Vikas|      Wallet|     Tanvi|                   27|      265|   T043|  Completed|        Mini|
# |Mumbai|       18.0|      Vikas|         UPI|     Pooja|                   45|      560|   T004|  Cancelled|         SUV|
# |Mumbai|       20.5|      Vijay|        Card|     Vikas|                   50|      650|   T009|  Completed|         SUV|
# |Mumbai|       10.2|      Vikas|      Wallet|     Divya|                   26|      260|   T014|  Completed|        Mini|
# |Mumbai|        9.9|      Vijay|         UPI|    Ayesha|                   24|      250|   T019|  Completed|        Mini|
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+

# %%
mumbai = mumbai.withColumn("fare_per_km", col("trip_fare")/col("distance_km"))
mumbai.show()
# Out:
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+------------------+
# |  city|distance_km|driver_name|payment_mode|rider_name|trip_duration_minutes|trip_fare|trip_id|trip_status|vehicle_type|       fare_per_km|
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+------------------+
# |Mumbai|       13.9|      Vikas|      Wallet|    Sameer|                   31|      350|   T024|  Completed|       Sedan|25.179856115107913|
# |Mumbai|       23.4|      Vijay|        Card|     Irfan|                   58|      740|   T028|  Completed|         SUV|31.623931623931625|
# |Mumbai|       15.8|      Vikas|        Card|      Aman|                   35|      395|   T033|  Completed|       Sedan|              25.0|
# |Mumbai|       21.7|      Vijay|        Card|     Sonia|                   54|      690|   T038|  Completed|         SUV|31.797235023041477|
# |Mumbai|       10.4|      Vikas|      Wallet|     Tanvi|                   27|      265|   T043|  Completed|        Mini| 25.48076923076923|
# |Mumbai|       18.0|      Vikas|         UPI|     Pooja|                   45|      560|   T004|  Cancelled|         SUV| 31.11111111111111|
# |Mumbai|       20.5|      Vijay|        Card|     Vikas|                   50|      650|   T009|  Completed|         SUV| 31.70731707317073|
# |Mumbai|       10.2|      Vikas|      Wallet|     Divya|                   26|      260|   T014|  Completed|        Mini|25.490196078431374|
# |Mumbai|        9.9|      Vijay|         UPI|    Ayesha|                   24|      250|   T019|  Completed|        Mini|25.252525252525253|
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+------------------+

# %%
mumbai.write.mode("overwrite").option("header", "true").json("mumbai_modified.json")

# %% [markdown]
# 7

# %%
ans = mumbai.filter((mumbai.payment_mode == "Card") & (mumbai.vehicle_type == "SUV")).show()
# Out:
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+------------------+
# |  city|distance_km|driver_name|payment_mode|rider_name|trip_duration_minutes|trip_fare|trip_id|trip_status|vehicle_type|       fare_per_km|
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+------------------+
# |Mumbai|       23.4|      Vijay|        Card|     Irfan|                   58|      740|   T028|  Completed|         SUV|31.623931623931625|
# |Mumbai|       21.7|      Vijay|        Card|     Sonia|                   54|      690|   T038|  Completed|         SUV|31.797235023041477|
# |Mumbai|       20.5|      Vijay|        Card|     Vikas|                   50|      650|   T009|  Completed|         SUV| 31.70731707317073|
# +------+-----------+-----------+------------+----------+---------------------+---------+-------+-----------+------------+------------------+

# %% [markdown]
# 8

# %%
mumbai.coalesce(1).write.mode("overwrite").json("mumbai_modified_partion.json")

# %% [markdown]
# 9

# %%
df.write.mode("overwrite").parquet("trips_parquet.parquet")

# %% [markdown]
# 10

# %%
x = spark.read.parquet("trips_parquet.parquet")
x.filter(x.trip_duration_minutes > 45).show()
# Out:
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |trip_id|rider_name|     city|driver_name|vehicle_type|distance_km|trip_fare|trip_duration_minutes|payment_mode|trip_status|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |   T028|     Irfan|   Mumbai|      Vijay|         SUV|       23.4|      740|                   58|        Card|  Completed|
# |   T035|     Zubin|    Delhi|       Anil|         SUV|       24.0|      760|                   60|        Card|  Completed|
# |   T038|     Sonia|   Mumbai|      Vijay|         SUV|       21.7|      690|                   54|        Card|  Completed|
# |   T042|     Mohit|Bangalore|     Suresh|         SUV|       19.9|      620|                   49|         UPI|  Completed|
# |   T009|     Vikas|   Mumbai|      Vijay|         SUV|       20.5|      650|                   50|        Card|  Completed|
# |   T012|     Megha|Hyderabad|     Ramesh|         SUV|       19.2|      610|                   48|        Card|     Cancel|
# |   T017|     Rohit|Hyderabad|     Ramesh|         SUV|       22.0|      700|                   55|        Card|  Completed|
# |   T022|      Yash|  Chennai|      Kumar|         SUV|       21.3|      680|                   52|         UPI|  Completed|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+

# %% [markdown]
# 11

# %%
short = x.sort(col("distance_km").desc()).limit(10)
short.write.mode("overwrite").parquet("trips_distance_km.parquet")

# %% [markdown]
# 14

# %%
spark.read \
    .option("header", "true") \
    .option("delimiter", ",") \
    .parquet("trips_distance_km.parquet").show()
# Out:
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |trip_id|rider_name|     city|driver_name|vehicle_type|distance_km|trip_fare|trip_duration_minutes|payment_mode|trip_status|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+
# |   T035|     Zubin|    Delhi|       Anil|         SUV|       24.0|      760|                   60|        Card|  Completed|
# |   T028|     Irfan|   Mumbai|      Vijay|         SUV|       23.4|      740|                   58|        Card|  Completed|
# |   T017|     Rohit|Hyderabad|     Ramesh|         SUV|       22.0|      700|                   55|        Card|  Completed|
# |   T038|     Sonia|   Mumbai|      Vijay|         SUV|       21.7|      690|                   54|        Card|  Completed|
# |   T022|      Yash|  Chennai|      Kumar|         SUV|       21.3|      680|                   52|         UPI|  Completed|
# |   T009|     Vikas|   Mumbai|      Vijay|         SUV|       20.5|      650|                   50|        Card|  Completed|
# |   T042|     Mohit|Bangalore|     Suresh|         SUV|       19.9|      620|                   49|         UPI|  Completed|
# |   T012|     Megha|Hyderabad|     Ramesh|         SUV|       19.2|      610|                   48|        Card|     Cancel|
# |   T004|     Pooja|   Mumbai|      Vikas|         SUV|       18.0|      560|                   45|         UPI|  Cancelled|
# |   T033|      Aman|   Mumbai|      Vikas|       Sedan|       15.8|      395|                   35|        Card|  Completed|
# +-------+----------+---------+-----------+------------+-----------+---------+---------------------+------------+-----------+

# %% [markdown]
# 15

# %%
fair = x.groupBy("city").agg(sum("trip_fare").alias("Total"))
fair.show()
# Out:
# +---------+-----+
# |     city|Total|
# +---------+-----+
# |Bangalore| 2590|
# |  Chennai| 2240|
# |   Mumbai| 4160|
# |    Delhi| 2895|
# |Hyderabad| 3310|
# +---------+-----+

# %% [markdown]
# 16

# %%
car = x.groupBy("vehicle_type").agg(sum("trip_fare").alias("Total"))
car.show()
# Out:
# +------------+-----+
# |vehicle_type|Total|
# +------------+-----+
# |        Bike| 1185|
# |        Mini| 3100|
# |         SUV| 6010|
# |       Sedan| 4900|
# +------------+-----+

# %% [markdown]
# 17

# %%
car = x.groupBy("vehicle_type").agg(count("trip_fare").alias("Total")).orderBy("Total",ascending=False)
car.show()
# Out:
# +------------+-----+
# |vehicle_type|Total|
# +------------+-----+
# |       Sedan|   14|
# |        Mini|   13|
# |        Bike|    9|
# |         SUV|    9|
# +------------+-----+

# %% [markdown]
# 18

# %% [markdown]
# Efficient for analytical queries ✔️ Compact file sizes (up to 90% smaller) ✔️ Works out of the box with Spark, Hive, Trino, Athena, DuckDB, and more ✔️ Optimized for modern CPU cache and disk I/O It’s not just another data format—it’s an architectural advantage.

# %% [markdown]
# C1

# %%
mumbai.coalesce(4).write.mode("overwrite").json("mumbai_modified_partion_4.json")

# %% [markdown]
# C2

# %%
from pyspark.sql.functions import count, sum, avg

summary_df = x.groupBy("city").agg(
    count("trip_id").alias("total_trips"),
    sum("trip_fare").alias("total_revenue"),
    avg("trip_duration_minutes").alias("average_trip_duration")
)

summary_df.show()
# Out:
# +---------+-----------+-------------+---------------------+
# |     city|total_trips|total_revenue|average_trip_duration|
# +---------+-----------+-------------+---------------------+
# |Bangalore|          9|         2590|    27.11111111111111|
# |  Chennai|          8|         2240|                 26.0|
# |   Mumbai|          9|         4160|   38.888888888888886|
# |    Delhi|         10|         2895|                 27.5|
# |Hyderabad|          9|         3310|    32.22222222222222|
# +---------+-----------+-------------+---------------------+

# %%
summary_df.write.mode("overwrite").parquet("city_trip_summary.parquet")
