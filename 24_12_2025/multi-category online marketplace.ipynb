# %% [markdown]
# <a href="https://colab.research.google.com/github/codingniket/Python-Training/blob/main/24_12_2025/multi-category%20online%20marketplace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://drive.google.com/file/d/1KKg-Ue_-SKaoyJkZCi2tyUwpcQcxS7V0/view

# %%
orders_data = [
    ("ORD001","C001","Delhi ","Electronics","Laptop","45000","2024-01-05","Completed"),
    ("ORD002","C002","Mumbai","Electronics","Mobile ","32000","05/01/2024","Completed"),
    ("ORD003","C003","Bangalore","Electronics","Tablet","30000","2024/01/06","Completed"),
    ("ORD004","C004","Delhi","Electronics","Laptop","","2024-01-07","Cancelled"),
    ("ORD005","C005","Chennai","Electronics","Mobile","invalid","2024-01-08","Completed"),
    ("ORD006","C006","Mumbai","Home","Mixer",None,"2024-01-08","Completed"),
    ("ORD007","C001","Delhi","Electronics","Laptop","47000","09-01-2024","Completed"),
    ("ORD008","C007","Bangalore","Home","Vacuum","28000","2024-01-09","Completed"),
    ("ORD009","C002","Mumbai","Electronics","Laptop","55000","2024-01-10","Completed"),
    ("ORD010","C008","Delhi","Home","AirPurifier","38000","2024-01-10","Completed"),
    ("ORD011","C009","Mumbai","Home","Vacuum","29000","2024-01-11","Completed"),
    ("ORD012","C010","Bangalore","Electronics","Mobile","33000","2024-01-11","Completed"),
    ("ORD013","C003","Bangalore","Home","Mixer","21000","2024-01-12","Completed"),
    ("ORD014","C004","Delhi","Electronics","Tablet","26000","2024-01-12","Completed"),
    ("ORD015","C005","Chennai","Electronics","Laptop","62000","2024-01-13","Completed"),
    ("ORD016","C006","Mumbai","Home","AirPurifier","40000","2024-01-13","Completed"),
    ("ORD017","C007","Bangalore","Electronics","Laptop","51000","2024-01-14","Completed"),
    ("ORD018","C008","Delhi","Home","Vacuum","31000","2024-01-14","Completed"),
    ("ORD019","C009","Mumbai","Electronics","Tablet","29000","2024-01-15","Completed"),
    ("ORD020","C010","Bangalore","Electronics","Laptop","54000","2024-01-15","Completed"),
    ("ORD020","C010","Bangalore","Electronics","Laptop","54000","2024-01-15","Completed")
]

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType
from pyspark.sql.functions import trim, col, when, to_date, sum as spark_sum, avg, desc, rank, lit, coalesce, isnull,try_to_timestamp,regexp_extract
from pyspark.sql.window import Window

spark = SparkSession.builder.appName("OnlineMarketExercise").getOrCreate()

# %%
schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("city", StringType(), True),
    StructField("category", StringType(), True),
    StructField("product", StringType(), True),
    StructField("amount", StringType(), True),
    StructField("order_date", StringType(), True),
    StructField("status", StringType(), True)
])

# %%
df = spark.createDataFrame(orders_data, schema)

original_count = df.count()

# %%
original_count
# Out:
# 21

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- status: string (nullable = true)

# %%
string_columns = ["order_id", "customer_id", "city", "category", "product", "amount", "order_date", "status"]
for column in string_columns:
    df = df.withColumn(column, trim(col(column)))

# %%
numeric_price_str = regexp_extract(col("amount"), r"(\d+)", 0)
df = df.withColumn("amount",when((numeric_price_str == "") | numeric_price_str.isNull(), lit(0)).otherwise(numeric_price_str.cast('int')))

# %%
df = df.withColumn(
    "order_date",
    coalesce(
        to_date(try_to_timestamp(col("order_date"), lit("yyyy-MM-dd"))),
        to_date(try_to_timestamp(col("order_date"), lit("dd/MM/yyyy"))),
        to_date(try_to_timestamp(col("order_date"), lit("yyyy/MM/dd")))
    )
)

# %%
df.show()
# Out:
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
# |order_id|customer_id|     city|   category|    product|amount|order_date|   status|
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
# |  ORD001|       C001|    Delhi|Electronics|     Laptop| 45000|2024-01-05|Completed|
# |  ORD002|       C002|   Mumbai|Electronics|     Mobile| 32000|2024-01-05|Completed|
# |  ORD003|       C003|Bangalore|Electronics|     Tablet| 30000|2024-01-06|Completed|
# |  ORD004|       C004|    Delhi|Electronics|     Laptop|     0|2024-01-07|Cancelled|
# |  ORD005|       C005|  Chennai|Electronics|     Mobile|     0|2024-01-08|Completed|
# |  ORD006|       C006|   Mumbai|       Home|      Mixer|     0|2024-01-08|Completed|
# |  ORD007|       C001|    Delhi|Electronics|     Laptop| 47000|      NULL|Completed|
# |  ORD008|       C007|Bangalore|       Home|     Vacuum| 28000|2024-01-09|Completed|
# |  ORD009|       C002|   Mumbai|Electronics|     Laptop| 55000|2024-01-10|Completed|
# |  ORD010|       C008|    Delhi|       Home|AirPurifier| 38000|2024-01-10|Completed|
# |  ORD011|       C009|   Mumbai|       Home|     Vacuum| 29000|2024-01-11|Completed|
# |  ORD012|       C010|Bangalore|Electronics|     Mobile| 33000|2024-01-11|Completed|
# |  ORD013|       C003|Bangalore|       Home|      Mixer| 21000|2024-01-12|Completed|
# |  ORD014|       C004|    Delhi|Electronics|     Tablet| 26000|2024-01-12|Completed|
# |  ORD015|       C005|  Chennai|Electronics|     Laptop| 62000|2024-01-13|Completed|
# |  ORD016|       C006|   Mumbai|       Home|AirPurifier| 40000|2024-01-13|Completed|
# |  ORD017|       C007|Bangalore|Electronics|     Laptop| 51000|2024-01-14|Completed|
# |  ORD018|       C008|    Delhi|       Home|     Vacuum| 31000|2024-01-14|Completed|
# |  ORD019|       C009|   Mumbai|Electronics|     Tablet| 29000|2024-01-15|Completed|
# |  ORD020|       C010|Bangalore|Electronics|     Laptop| 54000|2024-01-15|Completed|
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
# only showing top 20 rows

# %%
df = df.dropDuplicates(["order_id"])

# %%
df = df.filter(col("status") == "Completed")

df = df.filter(col("amount").isNotNull())
df = df.filter(col("order_date").isNotNull())

cleaned_df = df
cleaned_count = cleaned_df.count()

# %%
# 11
print(f"Records before cleaning: {original_count}")
print(f"Records after cleaning: {cleaned_count}")

# 12
null_counts = cleaned_df.filter(
    col("order_id").isNull() | col("amount").isNull() | col("order_date").isNull()
).count()
print(f"No nulls in key columns: {null_counts == 0}")

# 13
cleaned_df.printSchema()

# 14
cleaned_df.groupBy("city").agg(spark_sum("amount").alias("total_revenue")).show()

# 15
cleaned_df.groupBy("category").agg(spark_sum("amount").alias("total_revenue")).show()

# 16
cleaned_df.groupBy("product").agg(spark_sum("amount").alias("total_revenue")).show()

# 17
cleaned_df.groupBy("city").agg(avg("amount").alias("avg_order_value")).show()
# Out:
# Records before cleaning: 21
# Records after cleaning: 18
# No nulls in key columns: True
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- status: string (nullable = true)
#
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|       217000|
# |  Chennai|        62000|
# |   Mumbai|       185000|
# |    Delhi|       140000|
# +---------+-------------+
#
# +-----------+-------------+
# |   category|total_revenue|
# +-----------+-------------+
# |       Home|       187000|
# |Electronics|       417000|
# +-----------+-------------+
#
# +-----------+-------------+
# |    product|total_revenue|
# +-----------+-------------+
# |     Vacuum|        88000|
# |AirPurifier|        78000|
# |     Laptop|       267000|
# |      Mixer|        21000|
# |     Mobile|        65000|
# |     Tablet|        85000|
# +-----------+-------------+
#
# +---------+------------------+
# |     city|   avg_order_value|
# +---------+------------------+
# |Bangalore|36166.666666666664|
# |  Chennai|           31000.0|
# |   Mumbai|30833.333333333332|
# |    Delhi|           35000.0|
# +---------+------------------+

# %%
# 18
cleaned_df.groupBy("product").agg(spark_sum("amount").alias("revenue")).orderBy(desc("revenue")).limit(3).show()

# 19
city_revenue = cleaned_df.groupBy("city").agg(spark_sum("amount").alias("total_revenue"))
window_spec_city = Window.orderBy(desc("total_revenue"))
city_revenue.withColumn("rank", rank().over(window_spec_city)).show()

# 20
product_revenue = cleaned_df.groupBy("category", "product").agg(spark_sum("amount").alias("revenue"))
window_spec_product = Window.partitionBy("category").orderBy(desc("revenue"))
product_revenue.withColumn("rank", rank().over(window_spec_product)).show()

# 21
product_revenue.withColumn("rank", rank().over(window_spec_product)).filter(col("rank") == 1).show()

# 22
cleaned_df.cache()

# 23
cleaned_df.groupBy("city").agg(spark_sum("amount").alias("total_revenue")).show()
cleaned_df.groupBy("category").agg(spark_sum("amount").alias("total_revenue")).show()
cleaned_df.groupBy("product").agg(spark_sum("amount").alias("total_revenue")).show()

# 24
agg_df = cleaned_df.groupBy("city").agg(spark_sum("amount").alias("total_revenue"))
agg_df.explain(True)
# Out:
# +-------+-------+
# |product|revenue|
# +-------+-------+
# | Laptop| 267000|
# | Vacuum|  88000|
# | Tablet|  85000|
# +-------+-------+
#
# +---------+-------------+----+
# |     city|total_revenue|rank|
# +---------+-------------+----+
# |Bangalore|       217000|   1|
# |   Mumbai|       185000|   2|
# |    Delhi|       140000|   3|
# |  Chennai|        62000|   4|
# +---------+-------------+----+
#
# +-----------+-----------+-------+----+
# |   category|    product|revenue|rank|
# +-----------+-----------+-------+----+
# |Electronics|     Laptop| 267000|   1|
# |Electronics|     Tablet|  85000|   2|
# |Electronics|     Mobile|  65000|   3|
# |       Home|     Vacuum|  88000|   1|
# |       Home|AirPurifier|  78000|   2|
# |       Home|      Mixer|  21000|   3|
# +-----------+-----------+-------+----+
#
# +-----------+-------+-------+----+
# |   category|product|revenue|rank|
# +-----------+-------+-------+----+
# |Electronics| Laptop| 267000|   1|
# |       Home| Vacuum|  88000|   1|
# +-----------+-------+-------+----+
#
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |    Delhi|       140000|
# |Bangalore|       217000|
# |   Mumbai|       185000|
# |  Chennai|        62000|
# +---------+-------------+
#
# +-----------+-------------+
# |   category|total_revenue|
# +-----------+-------------+
# |       Home|       187000|
# |Electronics|       417000|
# +-----------+-------------+
#
# +-----------+-------------+
# |    product|total_revenue|
# +-----------+-------------+
# |     Vacuum|        88000|
# |     Laptop|       267000|
# |     Tablet|        85000|
# |     Mobile|        65000|
# |AirPurifier|        78000|
# |      Mixer|        21000|
# +-----------+-------------+
#
# == Parsed Logical Plan ==
# 'Aggregate ['city], ['city, 'sum('amount) AS total_revenue#2492]
# +- Filter isnotnull(order_date#801)
#    +- Filter isnotnull(amount#800)
#       +- Filter (status#799 = Completed)
#          +- Deduplicate [order_id#792]
#             +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, amount#800, coalesce(to_date(try_to_timestamp(order_date#798, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), None, Some(Etc/UTC), true), to_date(try_to_timestamp(order_date#798, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), None, Some(Etc/UTC), true), to_date(try_to_timestamp(order_date#798, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false), None, Some(Etc/UTC), true)) AS order_date#801, status#799]
#                +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, CASE WHEN ((regexp_extract(amount#797, (\d+), 0) = ) OR isnull(regexp_extract(amount#797, (\d+), 0))) THEN 0 ELSE cast(regexp_extract(amount#797, (\d+), 0) as int) END AS amount#800, order_date#798, status#799]
#                   +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, amount#797, order_date#798, trim(status#779, None) AS status#799]
#                      +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, amount#797, trim(order_date#778, None) AS order_date#798, status#779]
#                         +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, trim(amount#777, None) AS amount#797, order_date#778, status#779]
#                            +- Project [order_id#792, customer_id#793, city#794, category#795, trim(product#776, None) AS product#796, amount#777, order_date#778, status#779]
#                               +- Project [order_id#792, customer_id#793, city#794, trim(category#775, None) AS category#795, product#776, amount#777, order_date#778, status#779]
#                                  +- Project [order_id#792, customer_id#793, trim(city#774, None) AS city#794, category#775, product#776, amount#777, order_date#778, status#779]
#                                     +- Project [order_id#792, trim(customer_id#773, None) AS customer_id#793, city#774, category#775, product#776, amount#777, order_date#778, status#779]
#                                        +- Project [trim(order_id#772, None) AS order_id#792, customer_id#773, city#774, category#775, product#776, amount#777, order_date#778, status#779]
#                                           +- LogicalRDD [order_id#772, customer_id#773, city#774, category#775, product#776, amount#777, order_date#778, status#779], false
#
# == Analyzed Logical Plan ==
# city: string, total_revenue: bigint
# Aggregate [city#794], [city#794, sum(amount#800) AS total_revenue#2492L]
# +- Filter isnotnull(order_date#801)
#    +- Filter isnotnull(amount#800)
#       +- Filter (status#799 = Completed)
#          +- Deduplicate [order_id#792]
#             +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, amount#800, coalesce(to_date(try_to_timestamp(order_date#798, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), None, Some(Etc/UTC), true), to_date(try_to_timestamp(order_date#798, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), None, Some(Etc/UTC), true), to_date(try_to_timestamp(order_date#798, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false), None, Some(Etc/UTC), true)) AS order_date#801, status#799]
#                +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, CASE WHEN ((regexp_extract(amount#797, (\d+), 0) = ) OR isnull(regexp_extract(amount#797, (\d+), 0))) THEN 0 ELSE cast(regexp_extract(amount#797, (\d+), 0) as int) END AS amount#800, order_date#798, status#799]
#                   +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, amount#797, order_date#798, trim(status#779, None) AS status#799]
#                      +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, amount#797, trim(order_date#778, None) AS order_date#798, status#779]
#                         +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, trim(amount#777, None) AS amount#797, order_date#778, status#779]
#                            +- Project [order_id#792, customer_id#793, city#794, category#795, trim(product#776, None) AS product#796, amount#777, order_date#778, status#779]
#                               +- Project [order_id#792, customer_id#793, city#794, trim(category#775, None) AS category#795, product#776, amount#777, order_date#778, status#779]
#                                  +- Project [order_id#792, customer_id#793, trim(city#774, None) AS city#794, category#775, product#776, amount#777, order_date#778, status#779]
#                                     +- Project [order_id#792, trim(customer_id#773, None) AS customer_id#793, city#774, category#775, product#776, amount#777, order_date#778, status#779]
#                                        +- Project [trim(order_id#772, None) AS order_id#792, customer_id#773, city#774, category#775, product#776, amount#777, order_date#778, status#779]
#                                           +- LogicalRDD [order_id#772, customer_id#773, city#774, category#775, product#776, amount#777, order_date#778, status#779], false
#
# == Optimized Logical Plan ==
# Aggregate [city#794], [city#794, sum(amount#800) AS total_revenue#2492L]
# +- Project [city#794, amount#800]
#    +- InMemoryRelation [order_id#792, customer_id#793, city#794, category#795, product#796, amount#800, order_date#801, status#799], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- AdaptiveSparkPlan isFinalPlan=true
#             +- == Final Plan ==
#                ResultQueryStage 1
#                +- *(3) Filter (isnotnull(status#1729) AND ((status#1729 = Completed) AND (isnotnull(amount#1725) AND isnotnull(order_date#1727))))
#                   +- SortAggregate(key=[order_id#792], functions=[first(customer_id#793, false), first(city#794, false), first(category#795, false), first(product#796, false), first(amount#800, false), first(order_date#801, false), first(status#799, false)], output=[order_id#792, customer_id#1717, city#1719, category#1721, product#1723, amount#1725, order_date#1727, status#1729])
#                      +- *(2) Sort [order_id#792 ASC NULLS FIRST], false, 0
#                         +- ShuffleQueryStage 0
#                            +- Exchange hashpartitioning(order_id#792, 200), ENSURE_REQUIREMENTS, [plan_id=2815]
#                               +- SortAggregate(key=[order_id#792], functions=[partial_first(customer_id#793, false), partial_first(city#794, false), partial_first(category#795, false), partial_first(product#796, false), partial_first(amount#800, false), partial_first(order_date#801, false), partial_first(status#799, false)], output=[order_id#792, first#1744, valueSet#1745, first#1746, valueSet#1747, first#1748, valueSet#1749, first#1750, valueSet#1751, first#1752, valueSet#1753, first#1754, valueSet#1755, first#1756, valueSet#1757])
#                                  +- *(1) Sort [order_id#792 ASC NULLS FIRST], false, 0
#                                     +- *(1) Project [order_id#792, customer_id#793, city#794, category#795, product#796, CASE WHEN ((regexp_extract(amount#797, (\d+), 0) = ) OR isnull(regexp_extract(amount#797, (\d+), 0))) THEN 0 ELSE cast(regexp_extract(amount#797, (\d+), 0) as int) END AS amount#800, coalesce(cast(gettimestamp(order_date#798, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date)) AS order_date#801, status#799]
#                                        +- *(1) Project [trim(order_id#772, None) AS order_id#792, trim(customer_id#773, None) AS customer_id#793, trim(city#774, None) AS city#794, trim(category#775, None) AS category#795, trim(product#776, None) AS product#796, trim(amount#777, None) AS amount#797, trim(order_date#778, None) AS order_date#798, trim(status#779, None) AS status#799]
#                                           +- *(1) Scan ExistingRDD[order_id#772,customer_id#773,city#774,category#775,product#776,amount#777,order_date#778,status#779]
#             +- == Initial Plan ==
#                Filter (isnotnull(status#1729) AND ((status#1729 = Completed) AND (isnotnull(amount#1725) AND isnotnull(order_date#1727))))
#                +- SortAggregate(key=[order_id#792], functions=[first(customer_id#793, false), first(city#794, false), first(category#795, false), first(product#796, false), first(amount#800, false), first(order_date#801, false), first(status#799, false)], output=[order_id#792, customer_id#1717, city#1719, category#1721, product#1723, amount#1725, order_date#1727, status#1729])
#                   +- Sort [order_id#792 ASC NULLS FIRST], false, 0
#                      +- Exchange hashpartitioning(order_id#792, 200), ENSURE_REQUIREMENTS, [plan_id=2770]
#                         +- SortAggregate(key=[order_id#792], functions=[partial_first(customer_id#793, false), partial_first(city#794, false), partial_first(category#795, false), partial_first(product#796, false), partial_first(amount#800, false), partial_first(order_date#801, false), partial_first(status#799, false)], output=[order_id#792, first#1744, valueSet#1745, first#1746, valueSet#1747, first#1748, valueSet#1749, first#1750, valueSet#1751, first#1752, valueSet#1753, first#1754, valueSet#1755, first#1756, valueSet#1757])
#                            +- Sort [order_id#792 ASC NULLS FIRST], false, 0
#                               +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, CASE WHEN ((regexp_extract(amount#797, (\d+), 0) = ) OR isnull(regexp_extract(amount#797, (\d+), 0))) THEN 0 ELSE cast(regexp_extract(amount#797, (\d+), 0) as int) END AS amount#800, coalesce(cast(gettimestamp(order_date#798, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date)) AS order_date#801, status#799]
#                                  +- Project [trim(order_id#772, None) AS order_id#792, trim(customer_id#773, None) AS customer_id#793, trim(city#774, None) AS city#794, trim(category#775, None) AS category#795, trim(product#776, None) AS product#796, trim(amount#777, None) AS amount#797, trim(order_date#778, None) AS order_date#798, trim(status#779, None) AS status#799]
#                                     +- Scan ExistingRDD[order_id#772,customer_id#773,city#774,category#775,product#776,amount#777,order_date#778,status#779]
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[city#794], functions=[sum(amount#800)], output=[city#794, total_revenue#2492L])
#    +- Exchange hashpartitioning(city#794, 200), ENSURE_REQUIREMENTS, [plan_id=2992]
#       +- HashAggregate(keys=[city#794], functions=[partial_sum(amount#800)], output=[city#794, sum#2623L])
#          +- InMemoryTableScan [city#794, amount#800]
#                +- InMemoryRelation [order_id#792, customer_id#793, city#794, category#795, product#796, amount#800, order_date#801, status#799], StorageLevel(disk, memory, deserialized, 1 replicas)
#                      +- AdaptiveSparkPlan isFinalPlan=true
#                         +- == Final Plan ==
#                            ResultQueryStage 1
#                            +- *(3) Filter (isnotnull(status#1729) AND ((status#1729 = Completed) AND (isnotnull(amount#1725) AND isnotnull(order_date#1727))))
#                               +- SortAggregate(key=[order_id#792], functions=[first(customer_id#793, false), first(city#794, false), first(category#795, false), first(product#796, false), first(amount#800, false), first(order_date#801, false), first(status#799, false)], output=[order_id#792, customer_id#1717, city#1719, category#1721, product#1723, amount#1725, order_date#1727, status#1729])
#                                  +- *(2) Sort [order_id#792 ASC NULLS FIRST], false, 0
#                                     +- ShuffleQueryStage 0
#                                        +- Exchange hashpartitioning(order_id#792, 200), ENSURE_REQUIREMENTS, [plan_id=2815]
#                                           +- SortAggregate(key=[order_id#792], functions=[partial_first(customer_id#793, false), partial_first(city#794, false), partial_first(category#795, false), partial_first(product#796, false), partial_first(amount#800, false), partial_first(order_date#801, false), partial_first(status#799, false)], output=[order_id#792, first#1744, valueSet#1745, first#1746, valueSet#1747, first#1748, valueSet#1749, first#1750, valueSet#1751, first#1752, valueSet#1753, first#1754, valueSet#1755, first#1756, valueSet#1757])
#                                              +- *(1) Sort [order_id#792 ASC NULLS FIRST], false, 0
#                                                 +- *(1) Project [order_id#792, customer_id#793, city#794, category#795, product#796, CASE WHEN ((regexp_extract(amount#797, (\d+), 0) = ) OR isnull(regexp_extract(amount#797, (\d+), 0))) THEN 0 ELSE cast(regexp_extract(amount#797, (\d+), 0) as int) END AS amount#800, coalesce(cast(gettimestamp(order_date#798, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date)) AS order_date#801, status#799]
#                                                    +- *(1) Project [trim(order_id#772, None) AS order_id#792, trim(customer_id#773, None) AS customer_id#793, trim(city#774, None) AS city#794, trim(category#775, None) AS category#795, trim(product#776, None) AS product#796, trim(amount#777, None) AS amount#797, trim(order_date#778, None) AS order_date#798, trim(status#779, None) AS status#799]
#                                                       +- *(1) Scan ExistingRDD[order_id#772,customer_id#773,city#774,category#775,product#776,amount#777,order_date#778,status#779]
#                         +- == Initial Plan ==
#                            Filter (isnotnull(status#1729) AND ((status#1729 = Completed) AND (isnotnull(amount#1725) AND isnotnull(order_date#1727))))
#                            +- SortAggregate(key=[order_id#792], functions=[first(customer_id#793, false), first(city#794, false), first(category#795, false), first(product#796, false), first(amount#800, false), first(order_date#801, false), first(status#799, false)], output=[order_id#792, customer_id#1717, city#1719, category#1721, product#1723, amount#1725, order_date#1727, status#1729])
#                               +- Sort [order_id#792 ASC NULLS FIRST], false, 0
#                                  +- Exchange hashpartitioning(order_id#792, 200), ENSURE_REQUIREMENTS, [plan_id=2770]
#                                     +- SortAggregate(key=[order_id#792], functions=[partial_first(customer_id#793, false), partial_first(city#794, false), partial_first(category#795, false), partial_first(product#796, false), partial_first(amount#800, false), partial_first(order_date#801, false), partial_first(status#799, false)], output=[order_id#792, first#1744, valueSet#1745, first#1746, valueSet#1747, first#1748, valueSet#1749, first#1750, valueSet#1751, first#1752, valueSet#1753, first#1754, valueSet#1755, first#1756, valueSet#1757])
#                                        +- Sort [order_id#792 ASC NULLS FIRST], false, 0
#                                           +- Project [order_id#792, customer_id#793, city#794, category#795, product#796, CASE WHEN ((regexp_extract(amount#797, (\d+), 0) = ) OR isnull(regexp_extract(amount#797, (\d+), 0))) THEN 0 ELSE cast(regexp_extract(amount#797, (\d+), 0) as int) END AS amount#800, coalesce(cast(gettimestamp(order_date#798, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date), cast(gettimestamp(order_date#798, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date)) AS order_date#801, status#799]
#                                              +- Project [trim(order_id#772, None) AS order_id#792, trim(customer_id#773, None) AS customer_id#793, trim(city#774, None) AS city#794, trim(category#775, None) AS category#795, trim(product#776, None) AS product#796, trim(amount#777, None) AS amount#797, trim(order_date#778, None) AS order_date#798, trim(status#779, None) AS status#799]
#                                                 +- Scan ExistingRDD[order_id#772,customer_id#773,city#774,category#775,product#776,amount#777,order_date#778,status#779]

# %%
# 25
repartitioned_df = cleaned_df.repartition("city")
# Repartitioning by city groups data by city in partitions, reducing shuffle during city-based operations like groupBy("city")

# 26
cleaned_df.write.mode("overwrite").parquet("cleaned_orders.parquet")

# 27
city_revenue.write.mode("overwrite").orc("analytics.orc")

# 28
parquet_read = spark.read.parquet("cleaned_orders.parquet")
parquet_read.printSchema()
orc_read = spark.read.orc("analytics.orc")
orc_read.printSchema()

# 29
# The line is incorrect because .show() prints the DataFrame but returns None, so assigning it back to df sets df to None, losing the filtered data.

# 30
df = df.filter(df.amount > 30000)
df.show()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- status: string (nullable = true)
#
# root
#  |-- city: string (nullable = true)
#  |-- total_revenue: long (nullable = true)
#
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
# |order_id|customer_id|     city|   category|    product|amount|order_date|   status|
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
# |  ORD018|       C008|    Delhi|       Home|     Vacuum| 31000|2024-01-14|Completed|
# |  ORD001|       C001|    Delhi|Electronics|     Laptop| 45000|2024-01-05|Completed|
# |  ORD002|       C002|   Mumbai|Electronics|     Mobile| 32000|2024-01-05|Completed|
# |  ORD017|       C007|Bangalore|Electronics|     Laptop| 51000|2024-01-14|Completed|
# |  ORD016|       C006|   Mumbai|       Home|AirPurifier| 40000|2024-01-13|Completed|
# |  ORD015|       C005|  Chennai|Electronics|     Laptop| 62000|2024-01-13|Completed|
# |  ORD012|       C010|Bangalore|Electronics|     Mobile| 33000|2024-01-11|Completed|
# |  ORD020|       C010|Bangalore|Electronics|     Laptop| 54000|2024-01-15|Completed|
# |  ORD009|       C002|   Mumbai|Electronics|     Laptop| 55000|2024-01-10|Completed|
# |  ORD010|       C008|    Delhi|       Home|AirPurifier| 38000|2024-01-10|Completed|
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
